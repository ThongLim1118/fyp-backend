# %%
import pandas as pd
import os

# 1. Define the full path to your data file
# Assuming your data is in the default Freqtrade user_data/data/binance/ directory
# Adjust the path below if your exchange or directory name is different.
file_path = os.path.join(
    'user_data',
    'data',
    'binance', # <-- Replace with your exchange if it's not binance
    'ETH_USDT-1d.feather'
)

# 2. Read the feather file into a pandas DataFrame
try:
    df = pd.read_feather(file_path)

    # 3. Print the first few rows to confirm it loaded correctly
    print("DataFrame successfully loaded:")
    print(df.head())

    # The data is now in 'df', and you can work with it:
    # print(df.columns)
    # print(df.info())

except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}. Check your path and filename.")
except Exception as e:
    print(f"An error occurred: {e}")
